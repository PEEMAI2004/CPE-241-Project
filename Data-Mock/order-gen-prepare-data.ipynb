# %%
import requests
import time
import json

# %%
BEARER_TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImthbWluLmppdHRAbWFpbC5rbXV0dC5hYy50aCIsImV4cCI6MTc0NzY0MTc5OSwicm9sZV9pZCI6MSwidXNlcl9pZCI6MTM3fQ.cciC6ltW6usosrwZofDaYhYL73qRqzEY7uxjprB8pVU"  # Replace with your actual token
HEADERS = {
    "Authorization": f"Bearer {BEARER_TOKEN}"
}

# %% [markdown]
# ### Get Unsold Orders

# %%
import os

# === Configuration ===
BASE_URL = "https://postgrest.kaminjitt.com/honeystock"

LIMIT = 100000  # Batch size
MAX_BATCHES = 200  # Avoid infinite loops, adjust as needed
OUTPUT_FOLDER = "unsold_stocks_batches"

# Ensure the output folder exists
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

def fetch_batch(offset):
    params = {
        "is_sold": "eq.false",
        "select": "stock_id,stock_date",
        "order": "stock_date.asc",
        "limit": str(LIMIT),
        "offset": str(offset)
    }
    response = requests.get(BASE_URL, headers=HEADERS, params=params)
    response.raise_for_status()
    return response.json()

def fetch_all_unsold_stocks():
    offset = 0
    batch_num = 0

    while batch_num < MAX_BATCHES:
        print(f"📦 Fetching batch {batch_num + 1} (offset {offset})...")
        batch = fetch_batch(offset)
        if not batch:
            print("✅ No more records to fetch.")
            break

        # Save the batch to a file
        batch_file = os.path.join(OUTPUT_FOLDER, f"batch_{batch_num + 1}.json")
        with open(batch_file, "w", encoding="utf-8") as f:
            json.dump(batch, f, indent=2, ensure_ascii=False)
        print(f"✅ Saved batch {batch_num + 1} to {batch_file}")

        offset += LIMIT
        batch_num += 1
        time.sleep(0.2)  # Be kind to the server

    print(f"✅ Total batches fetched: {batch_num}")

if __name__ == "__main__":
    fetch_all_unsold_stocks()
# Out:
# 📦 Fetching batch 1 (offset 0)...
# ✅ Saved batch 1 to unsold_stocks_batches/batch_1.json
# 📦 Fetching batch 2 (offset 100000)...
# ✅ Saved batch 2 to unsold_stocks_batches/batch_2.json
# 📦 Fetching batch 3 (offset 200000)...
# ✅ Saved batch 3 to unsold_stocks_batches/batch_3.json
# 📦 Fetching batch 4 (offset 300000)...
# ✅ Saved batch 4 to unsold_stocks_batches/batch_4.json
# 📦 Fetching batch 5 (offset 400000)...
# ✅ Saved batch 5 to unsold_stocks_batches/batch_5.json
# 📦 Fetching batch 6 (offset 500000)...
# ✅ Saved batch 6 to unsold_stocks_batches/batch_6.json
# 📦 Fetching batch 7 (offset 600000)...
# ✅ Saved batch 7 to unsold_stocks_batches/batch_7.json
# 📦 Fetching batch 8 (offset 700000)...
# ✅ Saved batch 8 to unsold_stocks_batches/batch_8.json
# 📦 Fetching batch 9 (offset 800000)...
# ✅ Saved batch 9 to unsold_stocks_batches/batch_9.json
# 📦 Fetching batch 10 (offset 900000)...
# ✅ Saved batch 10 to unsold_stocks_batches/batch_10.json
# 📦 Fetching batch 11 (offset 1000000)...
# ✅ Saved batch 11 to unsold_stocks_batches/batch_11.json
# 📦 Fetching batch 12 (offset 1100000)...
# ✅ Saved batch 12 to unsold_stocks_batches/batch_12.json
# 📦 Fetching batch 13 (offset 1200000)...
# ✅ Saved batch 13 to unsold_stocks_batches/batch_13.json
# 📦 Fetching batch 14 (offset 1300000)...
# ✅ Saved batch 14 to unsold_stocks_batches/batch_14.json
# 📦 Fetching batch 15 (offset 1400000)...
# ✅ Saved batch 15 to unsold_stocks_batches/batch_15.json
# 📦 Fetching batch 16 (offset 1500000)...
# ✅ Saved batch 16 to unsold_stocks_batches/batch_16.json
# 📦 Fetching batch 17 (offset 1600000)...
# ✅ Saved batch 17 to unsold_stocks_batches/batch_17.json
# 📦 Fetching batch 18 (offset 1700000)...
# ✅ Saved batch 18 to unsold_stocks_batches/batch_18.json
# 📦 Fetching batch 19 (offset 1800000)...
# ✅ Saved batch 19 to unsold_stocks_batches/batch_19.json
# 📦 Fetching batch 20 (offset 1900000)...
# ✅ Saved batch 20 to unsold_stocks_batches/batch_20.json
# 📦 Fetching batch 21 (offset 2000000)...
# ✅ Saved batch 21 to unsold_stocks_batches/batch_21.json
# 📦 Fetching batch 22 (offset 2100000)...
# ✅ Saved batch 22 to unsold_stocks_batches/batch_22.json
# 📦 Fetching batch 23 (offset 2200000)...
# ✅ Saved batch 23 to unsold_stocks_batches/batch_23.json
# 📦 Fetching batch 24 (offset 2300000)...
# ✅ Saved batch 24 to unsold_stocks_batches/batch_24.json
# 📦 Fetching batch 25 (offset 2400000)...
# ✅ Saved batch 25 to unsold_stocks_batches/batch_25.json
# 📦 Fetching batch 26 (offset 2500000)...
# ✅ Saved batch 26 to unsold_stocks_batches/batch_26.json
# 📦 Fetching batch 27 (offset 2600000)...
# ✅ Saved batch 27 to unsold_stocks_batches/batch_27.json
# 📦 Fetching batch 28 (offset 2700000)...
# ✅ Saved batch 28 to unsold_stocks_batches/batch_28.json
# 📦 Fetching batch 29 (offset 2800000)...
# ✅ Saved batch 29 to unsold_stocks_batches/batch_29.json
# 📦 Fetching batch 30 (offset 2900000)...
# ✅ Saved batch 30 to unsold_stocks_batches/batch_30.json
# 📦 Fetching batch 31 (offset 3000000)...
# ✅ Saved batch 31 to unsold_stocks_batches/batch_31.json
# 📦 Fetching batch 32 (offset 3100000)...
# ✅ Saved batch 32 to unsold_stocks_batches/batch_32.json
# 📦 Fetching batch 33 (offset 3200000)...
# ✅ Saved batch 33 to unsold_stocks_batches/batch_33.json
# 📦 Fetching batch 34 (offset 3300000)...
# ✅ Saved batch 34 to unsold_stocks_batches/batch_34.json
# 📦 Fetching batch 35 (offset 3400000)...
# ✅ Saved batch 35 to unsold_stocks_batches/batch_35.json
# 📦 Fetching batch 36 (offset 3500000)...
# ✅ Saved batch 36 to unsold_stocks_batches/batch_36.json
# 📦 Fetching batch 37 (offset 3600000)...
# ✅ Saved batch 37 to unsold_stocks_batches/batch_37.json
# 📦 Fetching batch 38 (offset 3700000)...
# ✅ Saved batch 38 to unsold_stocks_batches/batch_38.json
# 📦 Fetching batch 39 (offset 3800000)...
# ✅ Saved batch 39 to unsold_stocks_batches/batch_39.json
# 📦 Fetching batch 40 (offset 3900000)...
# ✅ Saved batch 40 to unsold_stocks_batches/batch_40.json
# 📦 Fetching batch 41 (offset 4000000)...
# ✅ Saved batch 41 to unsold_stocks_batches/batch_41.json
# 📦 Fetching batch 42 (offset 4100000)...
# ✅ Saved batch 42 to unsold_stocks_batches/batch_42.json
# 📦 Fetching batch 43 (offset 4200000)...
# ✅ Saved batch 43 to unsold_stocks_batches/batch_43.json
# 📦 Fetching batch 44 (offset 4300000)...
# ✅ Saved batch 44 to unsold_stocks_batches/batch_44.json
# 📦 Fetching batch 45 (offset 4400000)...
# ✅ Saved batch 45 to unsold_stocks_batches/batch_45.json
# 📦 Fetching batch 46 (offset 4500000)...
# ✅ Saved batch 46 to unsold_stocks_batches/batch_46.json
# 📦 Fetching batch 47 (offset 4600000)...
# ✅ Saved batch 47 to unsold_stocks_batches/batch_47.json
# 📦 Fetching batch 48 (offset 4700000)...
# ✅ Saved batch 48 to unsold_stocks_batches/batch_48.json
# 📦 Fetching batch 49 (offset 4800000)...
# ✅ Saved batch 49 to unsold_stocks_batches/batch_49.json
# 📦 Fetching batch 50 (offset 4900000)...
# ✅ Saved batch 50 to unsold_stocks_batches/batch_50.json
# 📦 Fetching batch 51 (offset 5000000)...
# ✅ Saved batch 51 to unsold_stocks_batches/batch_51.json
# 📦 Fetching batch 52 (offset 5100000)...
# ✅ Saved batch 52 to unsold_stocks_batches/batch_52.json
# 📦 Fetching batch 53 (offset 5200000)...
# ✅ Saved batch 53 to unsold_stocks_batches/batch_53.json
# 📦 Fetching batch 54 (offset 5300000)...
# ✅ Saved batch 54 to unsold_stocks_batches/batch_54.json
# 📦 Fetching batch 55 (offset 5400000)...
# ✅ Saved batch 55 to unsold_stocks_batches/batch_55.json
# 📦 Fetching batch 56 (offset 5500000)...
# ✅ Saved batch 56 to unsold_stocks_batches/batch_56.json
# 📦 Fetching batch 57 (offset 5600000)...
# ✅ Saved batch 57 to unsold_stocks_batches/batch_57.json
# 📦 Fetching batch 58 (offset 5700000)...
# ✅ Saved batch 58 to unsold_stocks_batches/batch_58.json
# 📦 Fetching batch 59 (offset 5800000)...
# ✅ Saved batch 59 to unsold_stocks_batches/batch_59.json
# 📦 Fetching batch 60 (offset 5900000)...
# ✅ Saved batch 60 to unsold_stocks_batches/batch_60.json
# 📦 Fetching batch 61 (offset 6000000)...
# ✅ Saved batch 61 to unsold_stocks_batches/batch_61.json
# 📦 Fetching batch 62 (offset 6100000)...
# ✅ Saved batch 62 to unsold_stocks_batches/batch_62.json
# 📦 Fetching batch 63 (offset 6200000)...
# ✅ Saved batch 63 to unsold_stocks_batches/batch_63.json
# 📦 Fetching batch 64 (offset 6300000)...
# ✅ Saved batch 64 to unsold_stocks_batches/batch_64.json
# 📦 Fetching batch 65 (offset 6400000)...
# ✅ Saved batch 65 to unsold_stocks_batches/batch_65.json
# 📦 Fetching batch 66 (offset 6500000)...
# ✅ Saved batch 66 to unsold_stocks_batches/batch_66.json
# 📦 Fetching batch 67 (offset 6600000)...
# ✅ Saved batch 67 to unsold_stocks_batches/batch_67.json
# 📦 Fetching batch 68 (offset 6700000)...
# ✅ Saved batch 68 to unsold_stocks_batches/batch_68.json
# 📦 Fetching batch 69 (offset 6800000)...
# ✅ Saved batch 69 to unsold_stocks_batches/batch_69.json
# 📦 Fetching batch 70 (offset 6900000)...
# ✅ Saved batch 70 to unsold_stocks_batches/batch_70.json
# 📦 Fetching batch 71 (offset 7000000)...
# ✅ Saved batch 71 to unsold_stocks_batches/batch_71.json
# 📦 Fetching batch 72 (offset 7100000)...
# ✅ Saved batch 72 to unsold_stocks_batches/batch_72.json
# 📦 Fetching batch 73 (offset 7200000)...
# ✅ Saved batch 73 to unsold_stocks_batches/batch_73.json
# 📦 Fetching batch 74 (offset 7300000)...
# ✅ Saved batch 74 to unsold_stocks_batches/batch_74.json
# 📦 Fetching batch 75 (offset 7400000)...
# ✅ Saved batch 75 to unsold_stocks_batches/batch_75.json
# 📦 Fetching batch 76 (offset 7500000)...
# ✅ Saved batch 76 to unsold_stocks_batches/batch_76.json
# 📦 Fetching batch 77 (offset 7600000)...
# ✅ Saved batch 77 to unsold_stocks_batches/batch_77.json
# 📦 Fetching batch 78 (offset 7700000)...
# ✅ Saved batch 78 to unsold_stocks_batches/batch_78.json
# 📦 Fetching batch 79 (offset 7800000)...
# ✅ Saved batch 79 to unsold_stocks_batches/batch_79.json
# 📦 Fetching batch 80 (offset 7900000)...
# ✅ Saved batch 80 to unsold_stocks_batches/batch_80.json
# 📦 Fetching batch 81 (offset 8000000)...
# ✅ Saved batch 81 to unsold_stocks_batches/batch_81.json
# 📦 Fetching batch 82 (offset 8100000)...
# ✅ Saved batch 82 to unsold_stocks_batches/batch_82.json
# 📦 Fetching batch 83 (offset 8200000)...
# ✅ Saved batch 83 to unsold_stocks_batches/batch_83.json
# 📦 Fetching batch 84 (offset 8300000)...
# ✅ Saved batch 84 to unsold_stocks_batches/batch_84.json
# 📦 Fetching batch 85 (offset 8400000)...
# ✅ Saved batch 85 to unsold_stocks_batches/batch_85.json
# 📦 Fetching batch 86 (offset 8500000)...
# ✅ Saved batch 86 to unsold_stocks_batches/batch_86.json
# 📦 Fetching batch 87 (offset 8600000)...
# ✅ Saved batch 87 to unsold_stocks_batches/batch_87.json
# 📦 Fetching batch 88 (offset 8700000)...
# ✅ Saved batch 88 to unsold_stocks_batches/batch_88.json
# 📦 Fetching batch 89 (offset 8800000)...
# ✅ Saved batch 89 to unsold_stocks_batches/batch_89.json
# 📦 Fetching batch 90 (offset 8900000)...
# ✅ Saved batch 90 to unsold_stocks_batches/batch_90.json
# 📦 Fetching batch 91 (offset 9000000)...
# ✅ Saved batch 91 to unsold_stocks_batches/batch_91.json
# 📦 Fetching batch 92 (offset 9100000)...
# ✅ Saved batch 92 to unsold_stocks_batches/batch_92.json
# 📦 Fetching batch 93 (offset 9200000)...
# ✅ Saved batch 93 to unsold_stocks_batches/batch_93.json
# 📦 Fetching batch 94 (offset 9300000)...
# ✅ Saved batch 94 to unsold_stocks_batches/batch_94.json
# 📦 Fetching batch 95 (offset 9400000)...
# ✅ Saved batch 95 to unsold_stocks_batches/batch_95.json
# 📦 Fetching batch 96 (offset 9500000)...
# ✅ Saved batch 96 to unsold_stocks_batches/batch_96.json
# 📦 Fetching batch 97 (offset 9600000)...
# ✅ Saved batch 97 to unsold_stocks_batches/batch_97.json
# 📦 Fetching batch 98 (offset 9700000)...
# ✅ Saved batch 98 to unsold_stocks_batches/batch_98.json
# 📦 Fetching batch 99 (offset 9800000)...
# ✅ Saved batch 99 to unsold_stocks_batches/batch_99.json
# 📦 Fetching batch 100 (offset 9900000)...
# ✅ Saved batch 100 to unsold_stocks_batches/batch_100.json
# 📦 Fetching batch 101 (offset 10000000)...
# ✅ Saved batch 101 to unsold_stocks_batches/batch_101.json
# 📦 Fetching batch 102 (offset 10100000)...
# ✅ Saved batch 102 to unsold_stocks_batches/batch_102.json
# 📦 Fetching batch 103 (offset 10200000)...
# ✅ Saved batch 103 to unsold_stocks_batches/batch_103.json
# 📦 Fetching batch 104 (offset 10300000)...
# ✅ Saved batch 104 to unsold_stocks_batches/batch_104.json
# 📦 Fetching batch 105 (offset 10400000)...
# ✅ Saved batch 105 to unsold_stocks_batches/batch_105.json
# 📦 Fetching batch 106 (offset 10500000)...
# ✅ Saved batch 106 to unsold_stocks_batches/batch_106.json
# 📦 Fetching batch 107 (offset 10600000)...
# ✅ Saved batch 107 to unsold_stocks_batches/batch_107.json
# 📦 Fetching batch 108 (offset 10700000)...
# ✅ Saved batch 108 to unsold_stocks_batches/batch_108.json
# 📦 Fetching batch 109 (offset 10800000)...
# ✅ Saved batch 109 to unsold_stocks_batches/batch_109.json
# 📦 Fetching batch 110 (offset 10900000)...
# ✅ Saved batch 110 to unsold_stocks_batches/batch_110.json
# 📦 Fetching batch 111 (offset 11000000)...
# ✅ Saved batch 111 to unsold_stocks_batches/batch_111.json
# 📦 Fetching batch 112 (offset 11100000)...
# ✅ Saved batch 112 to unsold_stocks_batches/batch_112.json
# 📦 Fetching batch 113 (offset 11200000)...
# ✅ Saved batch 113 to unsold_stocks_batches/batch_113.json
# 📦 Fetching batch 114 (offset 11300000)...
# ✅ Saved batch 114 to unsold_stocks_batches/batch_114.json
# 📦 Fetching batch 115 (offset 11400000)...
# ✅ Saved batch 115 to unsold_stocks_batches/batch_115.json
# 📦 Fetching batch 116 (offset 11500000)...
# ✅ No more records to fetch.
# ✅ Total batches fetched: 115

# %% [markdown]
# ### Get Customers

# %%
API_URL = "https://postgrest.kaminjitt.com/customer?select=customer_id"

# === Fetch and Save ===
def fetch_customer_ids():
    response = requests.get(API_URL, headers=HEADERS)
    response.raise_for_status()
    data = response.json()

    customer_ids = [entry['customer_id'] for entry in data]

    with open("customer_ids.json", "w", encoding="utf-8") as f:
        json.dump(customer_ids, f, indent=2, ensure_ascii=False)

    print(f"✅ Saved {len(customer_ids)} customer IDs to customer_ids.json")

if __name__ == "__main__":
    fetch_customer_ids()
# Out:
# ✅ Saved 10000 customer IDs to customer_ids.json

# %% [markdown]
# ### Get Shopkeeper Web Users

# %%
API_URL = "https://postgrest.kaminjitt.com/webuser"

# === Fetch user_id where role_id == 4 ===
def fetch_user_ids_with_role_4():
    params = {
        "role_id": "eq.4",
        "select": "user_id"
    }

    response = requests.get(API_URL, headers=HEADERS, params=params)
    response.raise_for_status()
    data = response.json()

    user_ids = [entry['user_id'] for entry in data]

    with open("user_ids_role_4.json", "w", encoding="utf-8") as f:
        json.dump(user_ids, f, indent=2, ensure_ascii=False)

    print(f"✅ Saved {len(user_ids)} user IDs with role_id=4 to user_ids_role_4.json")

if __name__ == "__main__":
    fetch_user_ids_with_role_4()
# Out:
# ✅ Saved 27 user IDs with role_id=4 to user_ids_role_4.json
